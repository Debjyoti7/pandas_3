# %%
import pandas as pd

# %%
df = pd.read_csv('test3.csv')

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][2:16]
# Out:
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# 13                          Andersson, Mr. Anders Johan
# 14                 Vestrom, Miss. Hulda Amanda Adolfina
# 15                     Hewlett, Mrs. (Mary D Kingcome)
# Name: Name, dtype: object

# %%
list(df['Name'])
# Out:
# ['Braund, Mr. Owen Harris',
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#  'Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry',
#  'Moran, Mr. James',
#  'McCarthy, Mr. Timothy J',
#  'Palsson, Master. Gosta Leonard',
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  'Nasser, Mrs. Nicholas (Adele Achem)',
#  'Sandstrom, Miss. Marguerite Rut',
#  'Bonnell, Miss. Elizabeth',
#  'Saundercock, Mr. William Henry',
#  'Andersson, Mr. Anders Johan',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Hewlett, Mrs. (Mary D Kingcome) ',
#  'Rice, Master. Eugene',
#  'Williams, Mr. Charles Eugene',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Masselmani, Mrs. Fatima',
#  'Fynney, Mr. Joseph J',
#  'Beesley, Mr. Lawrence',
#  'McGowan, Miss. Anna "Annie"',
#  'Sloper, Mr. William Thompson',
#  'Palsson, Miss. Torborg Danira',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
# ...

# %%
l = ['q','q','r','t','f']

# %%
pd.Series(l)
# Out:
# 0    q
# 1    q
# 2    r
# 3    t
# 4    f
# dtype: object

# %%
s = pd.Series(list(df['Name'][2:9]) , index = ['a','b','c','d','e','f','g'])

# %%
s
# Out:
# a                               Heikkinen, Miss. Laina
# b         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                             Allen, Mr. William Henry
# d                                     Moran, Mr. James
# e                              McCarthy, Mr. Timothy J
# f                       Palsson, Master. Gosta Leonard
# g    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# dtype: object

# %%
s1 = df['Name'][5:13]

# %%
s2 = s.append(s1)
# Out:
# /tmp/ipykernel_70/3943142441.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2 = s.append(s1)

# %%
s2
# Out:
# a                                Heikkinen, Miss. Laina
# b          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                              Allen, Mr. William Henry
# d                                      Moran, Mr. James
# e                               McCarthy, Mr. Timothy J
# f                        Palsson, Master. Gosta Leonard
# g     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# 11                             Bonnell, Miss. Elizabeth
# 12                       Saundercock, Mr. William Henry
# dtype: object

# %%
df.drop('PassengerId' , axis = 1)
# Out:
#      Unnamed: 0  Survived  Pclass  \
# 0             0         0       3
# 1             1         1       1
# 2             2         1       3
# 3             3         1       1
# 4             4         0       3
# ..          ...       ...     ...
# 886         886         0       2
# 887         887         1       1
# 888         888         0       3
# 889         889         1       1
# 890         890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.drop(2)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 3             3            4         1       1
# 4             4            5         0       3
# 5             5            6         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.set_index('Name', inplace = True)

# %%
df
# Out:
#                                                     Unnamed: 0  PassengerId  \
# Name
# Braund, Mr. Owen Harris                                      0            1
# Cumings, Mrs. John Bradley (Florence Briggs Tha...           1            2
# Heikkinen, Miss. Laina                                       2            3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                 3            4
# Allen, Mr. William Henry                                     4            5
# ...                                                        ...          ...
# Montvila, Rev. Juozas                                      886          887
# Graham, Miss. Margaret Edith                               887          888
# Johnston, Miss. Catherine Helen "Carrie"                   888          889
# Behr, Mr. Karl Howell                                      889          890
# Dooley, Mr. Patrick                                        890          891
#
# ...

# %%
df.loc['Futrelle, Mrs. Jacques Heath (Lily May Peel)']
# Out:
# Unnamed: 0          3
# PassengerId         4
# Survived            1
# Pclass              1
# Sex            female
# Age              35.0
# SibSp               1
# Parch               0
# Ticket         113803
# Fare             53.1
# Cabin            C123
# Embarked            S
# Name: Futrelle, Mrs. Jacques Heath (Lily May Peel), dtype: object

# %%
df.iloc[5]
# Out:
# Unnamed: 0          5
# PassengerId         6
# Survived            0
# Pclass              3
# Sex              male
# Age               NaN
# SibSp               0
# Parch               0
# Ticket         330877
# Fare           8.4583
# Cabin             NaN
# Embarked            Q
# Name: Moran, Mr. James, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                                   Name  Unnamed: 0  \
# 0                              Braund, Mr. Owen Harris           0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2                               Heikkinen, Miss. Laina           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           3
# 4                             Allen, Mr. William Henry           4
# ..                                                 ...         ...
# 886                              Montvila, Rev. Juozas         886
# 887                       Graham, Miss. Margaret Edith         887
# 888           Johnston, Miss. Catherine Helen "Carrie"         888
# 889                              Behr, Mr. Karl Howell         889
# 890                                Dooley, Mr. Patrick         890
#
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# ...

# %%
d = {'key1' : [1,2,3,4],
     'key2' : [5,8,1,2],
     'key3' : [8,9,6,7]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     5     8
# 1     2     8     9
# 2     3     1     6
# 3     4     2     7

# %%
df.dropna()
# Out:
#                                                   Name  Unnamed: 0  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           3
# 6                              McCarthy, Mr. Timothy J           6
# 10                     Sandstrom, Miss. Marguerite Rut          10
# 11                            Bonnell, Miss. Elizabeth          11
# ..                                                 ...         ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)         871
# 872                           Carlsson, Mr. Frans Olof         872
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         879
# 887                       Graham, Miss. Margaret Edith         887
# 889                              Behr, Mr. Karl Howell         889
#
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch    Ticket  \
# 1              2         1       1  female  38.0      1      0  PC 17599
# ...

# %%
df.dropna(axis = 1)
# Out:
#                                                   Name  Unnamed: 0  \
# 0                              Braund, Mr. Owen Harris           0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2                               Heikkinen, Miss. Laina           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           3
# 4                             Allen, Mr. William Henry           4
# ..                                                 ...         ...
# 886                              Montvila, Rev. Juozas         886
# 887                       Graham, Miss. Margaret Edith         887
# 888           Johnston, Miss. Catherine Helen "Carrie"         888
# 889                              Behr, Mr. Karl Howell         889
# 890                                Dooley, Mr. Patrick         890
#
#      PassengerId  Survived  Pclass     Sex  SibSp  Parch            Ticket  \
# 0              1         0       3    male      1      0         A/5 21171
# ...

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           3            4
# 4                           Allen, Mr. William Henry           4            5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# ...

# %%
df.fillna('deb')
# Out:
#                                                   Name  Unnamed: 0  \
# 0                              Braund, Mr. Owen Harris           0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2                               Heikkinen, Miss. Laina           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           3
# 4                             Allen, Mr. William Henry           4
# ..                                                 ...         ...
# 886                              Montvila, Rev. Juozas         886
# 887                       Graham, Miss. Margaret Edith         887
# 888           Johnston, Miss. Catherine Helen "Carrie"         888
# 889                              Behr, Mr. Karl Howell         889
# 890                                Dooley, Mr. Patrick         890
#
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# ...

# %%
df.groupby('Survived').mean()
# Out:
# /tmp/ipykernel_70/1397368861.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Survived').mean()
#           Unnamed: 0  PassengerId    Pclass        Age     SibSp     Parch  \
# Survived
# 0         446.016393   447.016393  2.531876  30.626179  0.553734  0.329690
# 1         443.368421   444.368421  1.950292  28.343690  0.473684  0.464912
#
#                Fare
# Survived
# 0         22.117887
# 1         48.395408

# %%
df.groupby('Sex').mean()
# Out:
# /tmp/ipykernel_70/3123540612.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Sex').mean()
#         Unnamed: 0  PassengerId  Survived    Pclass        Age     SibSp  \
# Sex
# female  430.028662   431.028662  0.742038  2.159236  27.915709  0.694268
# male    453.147314   454.147314  0.188908  2.389948  30.726645  0.429809
#
#            Parch       Fare
# Sex
# female  0.649682  44.479818
# male    0.235702  25.523893

# %%
df1 = df.groupby('Pclass').sum()
# Out:
# /tmp/ipykernel_70/1578990051.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = df.groupby('Pclass').sum()

# %%
df1
# Out:
#         Unnamed: 0  PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            99489        99705       136  7111.42     90     77  18177.4125
# 2            81872        82056        87  5168.83     74     70   3801.8417
# 3           215134       215625       119  8924.92    302    193   6714.6951

# %%
df1.T
# Out:
# Pclass                1           2            3
# Unnamed: 0   99489.0000  81872.0000  215134.0000
# PassengerId  99705.0000  82056.0000  215625.0000
# Survived       136.0000     87.0000     119.0000
# Age           7111.4200   5168.8300    8924.9200
# SibSp           90.0000     74.0000     302.0000
# Parch           77.0000     70.0000     193.0000
# Fare         18177.4125   3801.8417    6714.6951

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           3            4
# 4                           Allen, Mr. William Henry           4            5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# ...

# %%
df2 = df[['Name','PassengerId'	,'Survived']][0:5]

# %%
df2
# Out:
#                                                 Name  PassengerId  Survived
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0

# %%
df3 = df[['Name','PassengerId'	,'Survived']][5:10]

# %%
df3
# Out:
#                                                 Name  PassengerId  Survived
# 5                                   Moran, Mr. James            6         0
# 6                            McCarthy, Mr. Timothy J            7         0
# 7                     Palsson, Master. Gosta Leonard            8         0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                Nasser, Mrs. Nicholas (Adele Achem)           10         1

# %%
pd.concat([df2,df3])
# Out:
#                                                 Name  PassengerId  Survived
# 0                            Braund, Mr. Owen Harris            1         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                             Heikkinen, Miss. Laina            3         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                           Allen, Mr. William Henry            5         0
# 5                                   Moran, Mr. James            6         0
# 6                            McCarthy, Mr. Timothy J            7         0
# 7                     Palsson, Master. Gosta Leonard            8         0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)            9         1
# 9                Nasser, Mrs. Nicholas (Adele Achem)           10         1

# %%
df4 = pd.concat([df2,df3], axis = 1)

# %%
df4
# Out:
#                                                 Name  PassengerId  Survived  \
# 0                            Braund, Mr. Owen Harris          1.0       0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...          2.0       1.0
# 2                             Heikkinen, Miss. Laina          3.0       1.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)          4.0       1.0
# 4                           Allen, Mr. William Henry          5.0       0.0
# 5                                                NaN          NaN       NaN
# 6                                                NaN          NaN       NaN
# 7                                                NaN          NaN       NaN
# 8                                                NaN          NaN       NaN
# 9                                                NaN          NaN       NaN
#
#                                                 Name  PassengerId  Survived
# ...

# %%
df4.fillna('deb')
# Out:
#                                                 Name PassengerId Survived  \
# 0                            Braund, Mr. Owen Harris         1.0      0.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         2.0      1.0
# 2                             Heikkinen, Miss. Laina         3.0      1.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         4.0      1.0
# 4                           Allen, Mr. William Henry         5.0      0.0
# 5                                                deb         deb      deb
# 6                                                deb         deb      deb
# 7                                                deb         deb      deb
# 8                                                deb         deb      deb
# 9                                                deb         deb      deb
#
#                                                 Name PassengerId Survived
# 0                                                deb         deb      deb
# ...

# %%
d1 = {'key1' :[1,2,3,4],
      'key2': [12,3,4,15],
      'key3' : [7,8,9,3]
}

# %%
data1 = pd.DataFrame(d1)

# %%
d2 = {'key2' :[12,15,69,10],
      'key5' :[52,56,58,5],
      'key6' : [8,99,82,75]
    }

# %%
data2 = pd.DataFrame(d2)

# %%
data1
# Out:
#    key1  key2  key3
# 0     1    12     7
# 1     2     3     8
# 2     3     4     9
# 3     4    15     3

# %%
data2
# Out:
#    key2  key5  key6
# 0    12    52     8
# 1    15    56    99
# 2    69    58    82
# 3    10     5    75

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key5  key6
# 0     1    12     7    52     8
# 1     4    15     3    56    99

# %%
pd.merge(data1,data2, how = 'left')
# Out:
#    key1  key2  key3  key5  key6
# 0     1    12     7  52.0   8.0
# 1     2     3     8   NaN   NaN
# 2     3     4     9   NaN   NaN
# 3     4    15     3  56.0  99.0

# %%
pd.merge(data1,data2, how = 'cross')
# Out:
#     key1  key2_x  key3  key2_y  key5  key6
# 0      1      12     7      12    52     8
# 1      1      12     7      15    56    99
# 2      1      12     7      69    58    82
# 3      1      12     7      10     5    75
# 4      2       3     8      12    52     8
# 5      2       3     8      15    56    99
# 6      2       3     8      69    58    82
# 7      2       3     8      10     5    75
# 8      3       4     9      12    52     8
# 9      3       4     9      15    56    99
# 10     3       4     9      69    58    82
# 11     3       4     9      10     5    75
# 12     4      15     3      12    52     8
# 13     4      15     3      15    56    99
# 14     4      15     3      69    58    82
# 15     4      15     3      10     5    75

# %%
pd.merge(data1,data2, how = 'left', on = 'key2')
# Out:
#    key1  key2  key3  key5  key6
# 0     1    12     7  52.0   8.0
# 1     2     3     8   NaN   NaN
# 2     3     4     9   NaN   NaN
# 3     4    15     3  56.0  99.0

# %%
pd.merge(data1,data2, how = 'left', left_on = 'key1', right_on = 'key5' )
# Out:
#    key1  key2_x  key3  key2_y  key5  key6
# 0     1      12     7     NaN   NaN   NaN
# 1     2       3     8     NaN   NaN   NaN
# 2     3       4     9     NaN   NaN   NaN
# 3     4      15     3     NaN   NaN   NaN

# %%
data3 = pd.DataFrame({'key1' : [1,2,4,5,6],
                      'key2' : [4,5,6,7,8],
                      'key3' : [3,4,5,6,6]}, 
                    index = ['a','b','c','d','e'] 
                    )

# %%
data3
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data4 = pd.DataFrame({'key11' : [1,2,4,5,6],
                      'key22' : [4,5,6,7,8],
                      'key33' : [3,4,5,6,6]},
                     index = ['a','b','h','i','j']
)

# %%
data4
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      4      6      5
# i      5      7      6
# j      6      8      6

# %%
data3.join(data4)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data3.join(data4, how= 'inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
data3.join(data4, how= 'right')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0      1      4      3
# b   2.0   5.0   4.0      2      5      4
# h   NaN   NaN   NaN      4      6      5
# i   NaN   NaN   NaN      5      7      6
# j   NaN   NaN   NaN      6      8      6

# %%
data3.join(data4, how= 'outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0    6.0    5.0
# i   NaN   NaN   NaN    5.0    7.0    6.0
# j   NaN   NaN   NaN    6.0    8.0    6.0

# %%
data3.join(data4, how= 'cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3      4      6      5
# 3      1     4     3      5      7      6
# 4      1     4     3      6      8      6
# 5      2     5     4      1      4      3
# 6      2     5     4      2      5      4
# 7      2     5     4      4      6      5
# 8      2     5     4      5      7      6
# 9      2     5     4      6      8      6
# 10     4     6     5      1      4      3
# 11     4     6     5      2      5      4
# 12     4     6     5      4      6      5
# 13     4     6     5      5      7      6
# 14     4     6     5      6      8      6
# 15     5     7     6      1      4      3
# 16     5     7     6      2      5      4
# 17     5     7     6      4      6      5
# 18     5     7     6      5      7      6
# 19     5     7     6      6      8      6
# 20     6     8     6      1      4      3
# ...

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           3            4
# 4                           Allen, Mr. William Henry           4            5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked
# 0   NaN        S
# ...

# %%
df['Fare_inr']= df['Fare'].apply(lambda x : x*80)

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           3            4
# 4                           Allen, Mr. William Henry           4            5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked  Fare_inr
# ...

# %%
df['len_name'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#                                                 Name  Unnamed: 0  PassengerId  \
# 0                            Braund, Mr. Owen Harris           0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...           1            2
# 2                             Heikkinen, Miss. Laina           2            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)           3            4
# 4                           Allen, Mr. William Henry           4            5
#
#    Survived  Pclass     Sex   Age  SibSp  Parch            Ticket     Fare  \
# 0         0       3    male  22.0      1      0         A/5 21171   7.2500
# 1         1       1  female  38.0      1      0          PC 17599  71.2833
# 2         1       3  female  26.0      0      0  STON/O2. 3101282   7.9250
# 3         1       1  female  35.0      1      0            113803  53.1000
# 4         0       3    male  35.0      0      0            373450   8.0500
#
#   Cabin Embarked  Fare_inr  len_name
# ...

# %%
def create_flag(x):
    if x < 10:
        return 'cheap'
    elif x >= 10 and x < 20:
        return 'mid'
    else: 
        return 'high'

# %%
df['Flag_fare'] = df['Fare'].apply(create_flag)

# %%
df
# Out:
#                                                   Name  Unnamed: 0  \
# 0                              Braund, Mr. Owen Harris           0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...           1
# 2                               Heikkinen, Miss. Laina           2
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)           3
# 4                             Allen, Mr. William Henry           4
# ..                                                 ...         ...
# 886                              Montvila, Rev. Juozas         886
# 887                       Graham, Miss. Margaret Edith         887
# 888           Johnston, Miss. Catherine Helen "Carrie"         888
# 889                              Behr, Mr. Karl Howell         889
# 890                                Dooley, Mr. Patrick         890
#
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# ...
